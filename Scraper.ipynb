# %%
# Written by Omer Khan lmao 

# ______READ THIS PLEASE ________
# some baisc instructions on how to use this 

# create two text files, myfile.txt and data.txt

# enter a url for a product page 
# it will auto scroll to the reviews and read them the first time
# for it to read more you have to clcik on the next button in the reviews section
# after about 8 pages, you want to scroll to the reviews and stay there while it writes them down to a file. 
# Dont scroll further, it might present you with an error 

# this code will save mostly english reviews, but its a good idea to look through your saved text just in case. 
# Also it saves unique reviews, duplicates are removed

# ___________________________________

# pip install these libraries 
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time 
from langdetect import detect


# get the chrome driver here https://sites.google.com/chromium.org/driver/downloads
# check your chrome version too before downloading 
# download the chrome driver online and give its folder path here 

# my computer is a mac, so windows users do your own thing 
chromedriver_path= "/Users/admin/Downloads/chromedriver_mac64/chromedriver"


options = Options()
options.add_argument("--verbose")
# options.add_argument("--headless")
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

URL= input("Please enter a url:")
driver = webdriver.Chrome(options=options, executable_path=chromedriver_path)
# You can manually use this by using the line below 
# driver.get("https://www.daraz.pk/products/hot-best-selling-mini-small-leather-wallet-and-card-holder-stylish-slim-wallet-for-men-boys-brown-blue-camel-chocolate-i314509574-s1820724512.html?&search=pdp_v2v?spm=a2a0e.pdp.recommendation_1.5.df6cd8wPd8wPC5&mp=1&scm=1007.38553.252219.0&clickTrackInfo=af8bc2a4-956c-4a99-aa3a-826aa7aa0efb__314509574__10002040__cate__330312__0.483593__0.483593__0.0__0.0__0.0__0.0174844__4__null__null__null__null__null__null____150.0__0.19999999999999996__4.53147__143__120.0__153780,272585,272932__null__null__null__3650.16544_955.3632_4559.21183__null__28556__null__0.0__0.0________null__null")

driver.get(URL)
html = driver.find_element(By.TAG_NAME, 'html')

# this lets the page load, and also moves the page down so the reviews are loaded. 
# if your internet is faster you can reduce the time.sleep() time

x=0
while x<6: 
    time.sleep(.5)
    html.send_keys(Keys.PAGE_DOWN)
    x=x+1
    

# daraz loads reviews asynchronusly, ONLY FIVE AT A TIME LIKE WHAT EVEN
# its a huge pain because look at that atrocious class name for the button, it prevents me from being able to automate it 
# However I did find a crappy work around HAHAHA 
# So all you have to do is click on the next button and all the newly loaded reviews will be read. You have 10 seconds to click on the button to load more


# raw data will be written to myfile.txt, while filtered reviews will be written to data.txt
file1 = open("myfile.txt", "a")  # append mode

empty=""
# this will write all the reviews it picks up, regardless of duplicates
z=0
while z<10:
    for element in driver.find_elements_by_class_name('content'):
        TEXT= element.text
        if (len(TEXT)>0):
            if (detect(TEXT)=='en'): 
                file1.write(element.text+"\n")
                print (element.text)
        
    # driver.find_element_by_class_name('next-btn next-btn-normal next-btn-medium next-pagination-item next').click()
    # driver.find_element_by_xpath("//button[@class='next-btn_next-btn-normal_next-btn-medium next-pagination-item_next']").click()
    time.sleep(10)
    print (z)
    z=z+1

file1.close()


# removes duplicates and saves to data.txt
lines_seen = set() # holds lines already seen
outfile = open("data.txt", "a")
for line in open("myfile.txt", "r"):
    if line not in lines_seen: # not a duplicate
        outfile.write(line)
        lines_seen.add(line)
outfile.close()
# Out:
# thank you so much same as show and thank you so much for this gift
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good Excellent Baki Aik Reh Gaya Tha Wo Bhi send Kard Diya For Keychain Thanks Seller ❤️🙂👍 Highly Recommend 😊
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# As Salam Alikum sir as discuss hum sy ghlti hogaye ha we are extremly sorry apko solution b btaya ha
# bhut achi product he Bhai 10/10 no bilkul same as show picture❤️❤️❤️agli Barr insallha yahi se
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# 0
# NYS ❤️ Bhut Passand Aya Mujhy Or Thanks For Gift 🎁😊❤️🥰
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# good quality product
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Wallet is same as shown. All colour's are decent.Amazing in this price!!
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# 1
# 4.5/5
# 144 Ratings
# 121
# 4
# 5
# 3
# 11
# it's not leather it's a plastic third class low quality wallet🤬🤬🤬
# Thanks a lot for your review and bringing this issue to our attention. We’re extremely sorry to hear you had a disappointing experience with us. We’d love to make this right for you soon.
# very good product in this price small and smart 👌 wallet plus card holder thanks daraz thanks seller
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# 3rd class quality not leather.
# baby toy wallet. usually buy in market 50 to 60 rupees. for children..
# not adusting even cards.
# Thanks a lot for your review and bringing this issue to our attention. We’re extremely sorry to hear you had a disappointing experience with us. We’d love to make this right for you soon.
# bilkul he different product hy r silayan b Khrb hy jysa picture or purany reviews main tha wysa kuch b nai hy
# Mam kindly inbox us your issue we will solve your issue as soon as possible
# This Wallet is Very Slim And Stylish. Quality is Very Best And Also Excellent . THis Wallet is Not Expensive. I can,t Belive a small Amount of Money Is sending Best Quality of Wallet. TAHNKS Daraz
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# 2
# 4.5/5
# 144 Ratings
# 121
# 4
# 5
# 3
# 11
# Thats good🤗
# The quality of the wallet is very excellent Highly recommended Great product
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# It was my first experience with darax well it is good my product has been delivered in time this wallet is useful for keeping debit card and stuff like this and it is also called mini wallet well i like it .
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Excellent Quality same item received as shown in the picture
# reasonable price.   I  recommend this Seller to purchase items from thank.  👍
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# 3
# 4.5/5
# 144 Ratings
# 121
# 4
# 5
# 3
# 11
# normal quality and not too much good. quite good and neutral 😐.
# salam yeh leather ka nhi hai pure plastic ka hai Leather ka srif texture hai wallet me
# Sir is price mei leather ka apko kn dy skta ha sirf texture or syntetic leater hi mily ga na sir
# Sir 110 mei knsa orignal leather chahiye yahi synthetic leather hi aata ha bhai
# wow 😲 amazing wallet for men..it's so beautiful and smart wallet and fancy❤️🔥
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# size is small but quality is good 👍
# 4
# I am very happy because my dilivery is deliverd to me before a time.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good quality  ....and I am so happy after taking my first order
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good quality same as shown thanks to sellers for this best item
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# This really a amazing purse i am very thankful for daraz he sent me a amzing mini leather purse
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Great ordered one and got two.
# the size is also standard as shown in comparison with keys.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# 5
# I am very happy because my dilivery is deliverd to me before a time.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good quality  ....and I am so happy after taking my first order
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good quality same as shown thanks to sellers for this best item
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# This really a amazing purse i am very thankful for daraz he sent me a amzing mini leather purse
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Great ordered one and got two.
# the size is also standard as shown in comparison with keys.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# 6
# I am very happy because my dilivery is deliverd to me before a time.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good quality  ....and I am so happy after taking my first order
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good quality same as shown thanks to sellers for this best item
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# This really a amazing purse i am very thankful for daraz he sent me a amzing mini leather purse
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Great ordered one and got two.
# the size is also standard as shown in comparison with keys.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# 7
# I am very happy because my dilivery is deliverd to me before a time.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good quality  ....and I am so happy after taking my first order
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good quality same as shown thanks to sellers for this best item
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# This really a amazing purse i am very thankful for daraz he sent me a amzing mini leather purse
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Great ordered one and got two.
# the size is also standard as shown in comparison with keys.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# 8
# I am very happy because my dilivery is deliverd to me before a time.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good quality  ....and I am so happy after taking my first order
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Good quality same as shown thanks to sellers for this best item
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# This really a amazing purse i am very thankful for daraz he sent me a amzing mini leather purse
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# Great ordered one and got two.
# the size is also standard as shown in comparison with keys.
# Thank you so much for your lovely review. It’s so great to hear you enjoyed your experience with us. We hope to welcome you back again soon.
# 9
